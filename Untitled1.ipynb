# %% [markdown]
# <a href="https://colab.research.google.com/github/sreejamanthena10/travel_agent/blob/main/Untitled1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -qU langchain-google-genai langchain-community duckduckgo-search langchainhub faiss-cpu pypdf ddgs langchain-classic

import os
from google.colab import userdata

# Set your API Key (Save it in Colab Secrets as 'GOOGLE_API_KEY')
os.environ["GOOGLE_API_KEY"] = userdata.get('GOOGLE_API_KEY')

# %%
from langchain_google_genai import ChatGoogleGenerativeAI
from langchain_community.tools import DuckDuckGoSearchRun
from langchain_core.tools import create_retriever_tool
from langchain.agents import create_agent
# from langchain.agents.agent_executor import AgentExecutor # Trying alternative import for AgentExecutor
from langchainhub import pull # Corrected import for hub

# 1. Initialize the LLM (The Brain)
llm = ChatGoogleGenerativeAI(model="gemini-1.5-flash", temperature=0);

# 2. Setup the Tools (The Hands)
search = DuckDuckGoSearchRun()

# (Assuming your vector_db is already created from Phase 1)
# retriever_tool = create_retriever_tool(
#     vector_db.as_retriever(),
#     "hotel_booking_lookup",
#     "Use this for questions about the user's specific travel dates, hotel names, or booking IDs."
# )

tools = [search]

# 3. Create the Agent (The Logic)
# 'hwchase17/react' is a famous prompt that teaches the AI how to use tools
prompt = pull("hwchase17/react")

agent = create_agent(llm, tools, prompt)

# 4. The Executor (The Engine)
# agent_executor = AgentExecutor(
#     agent=agent,
#     tools=tools,
#     verbose=True, # Set to True to see the "Thinking" process!
#     handle_parsing_errors=True
# )

# 5. Test it!
# response = agent_executor.invoke({"input": "What is the current weather in Hyderabad?"})
# print(response["output"])
# Out:
# /usr/local/lib/python3.12/dist-packages/jupyter_client/session.py:203: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   return datetime.utcnow().replace(tzinfo=utc)
# /usr/local/lib/python3.12/dist-packages/jupyter_client/session.py:203: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   return datetime.utcnow().replace(tzinfo=utc)
# /usr/local/lib/python3.12/dist-packages/jupyter_client/session.py:203: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   return datetime.utcnow().replace(tzinfo=utc)
# ...

# %%
import langchain
print(f"LangChain version: {langchain.__version__}")
# Out:
# /usr/local/lib/python3.12/dist-packages/jupyter_client/session.py:203: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   return datetime.utcnow().replace(tzinfo=utc)
# /usr/local/lib/python3.12/dist-packages/jupyter_client/session.py:203: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   return datetime.utcnow().replace(tzinfo=utc)
# /usr/local/lib/python3.12/dist-packages/jupyter_client/session.py:203: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   return datetime.utcnow().replace(tzinfo=utc)
# ...

# %%
search.run("langchain AgentExecutor import path langchain 1.2.15")
# Out:
# /usr/local/lib/python3.12/dist-packages/jupyter_client/session.py:203: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   return datetime.utcnow().replace(tzinfo=utc)
# /usr/local/lib/python3.12/dist-packages/jupyter_client/session.py:203: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   return datetime.utcnow().replace(tzinfo=utc)
# /usr/local/lib/python3.12/dist-packages/jupyter_client/session.py:203: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   return datetime.utcnow().replace(tzinfo=utc)
# ...
