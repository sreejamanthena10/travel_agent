# %% [markdown]
# <a href="https://colab.research.google.com/github/sreejamanthena10/travel_agent/blob/main/RAG.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Force reinstall and install the core Track A stack
# !pip uninstall -y langchain langchain-google-genai langchain-community google-generativeai pydantic
# !pip install -q langchain==0.1.20 langchain-google-genai google-generativeai pypdf faiss-cpu langchain-community pydantic>=2

import os
from google.colab import userdata

# Secret Management using Colab's built-in tool
os.environ["GOOGLE_API_KEY"] = userdata.get('GOOGLE_API_KEY')

# Professional directory structure
os.makedirs('data/raw', exist_ok=True)
os.makedirs('data/processed', exist_ok=True)

print("✅ Environment ready. Upload your travel PDFs to the 'data/raw' folder in the sidebar.")
# Out:
# Found existing installation: langchain 0.1.20
# Uninstalling langchain-0.1.20:
#   Successfully uninstalled langchain-0.1.20
# Found existing installation: langchain-google-genai 1.0.4
# Uninstalling langchain-google-genai-1.0.4:
#   Successfully uninstalled langchain-google-genai-1.0.4
# Found existing installation: langchain-community 0.0.38
# Uninstalling langchain-community-0.0.38:
#   Successfully uninstalled langchain-community-0.0.38
# Found existing installation: google-generativeai 0.5.4
# Uninstalling google-generativeai-0.5.4:
#   Successfully uninstalled google-generativeai-0.5.4
# Found existing installation: pydantic 2.13.3
# Uninstalling pydantic-2.13.3:
#   Successfully uninstalled pydantic-2.13.3
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# langgraph-checkpoint 4.0.2 requires langchain-core>=0.2.38, but you have langchain-core 0.1.53 which is incompatible.
# langgraph-prebuilt 1.0.10 requires langchain-core>=1.0.0, but you have langchain-core 0.1.53 which is incompatible.
# langgraph 1.1.9 requires langchain-core<2,>=1.3.0, but you have langchain-core 0.1.53 which is incompatible.
# gradio 5.50.0 requires pydantic<=2.12.3,>=2.0, but you have pydantic 2.13.3 which is incompatible.
# google-adk 1.29.0 requires tenacity<10.0.0,>=9.0.0, but you have tenacity 8.5.0 which is incompatible.
# ✅ Environment ready. Upload your travel PDFs to the 'data/raw' folder in the sidebar.

# %%
# Move user-provided PDF files to the 'data/raw' directory
import shutil

source_files = [
    "/content/Hotel_Booking_Confirmation.pdf",
    "/content/Hyderabad_Travel_Brochure (1).pdf"
]

destination_dir = "./data/raw"

for file_path in source_files:
    if os.path.exists(file_path):
        shutil.move(file_path, destination_dir)
        print(f"Moved {os.path.basename(file_path)} to {destination_dir}")
    else:
        print(f"Warning: File not found at {file_path}")

print("\n--- Files in data/raw after moving ---")
print(os.listdir(destination_dir))
# Out:
# Warning: File not found at /content/Hotel_Booking_Confirmation.pdf
# Warning: File not found at /content/Hyderabad_Travel_Brochure (1).pdf
#
# --- Files in data/raw after moving ---
# ['Hotel_Booking_Confirmation.pdf', 'Hyderabad_Travel_Brochure (1).pdf']

# %%
from langchain_community.document_loaders import PyPDFLoader, DirectoryLoader
from langchain_text_splitters import RecursiveCharacterTextSplitter
from langchain_google_genai import GoogleGenerativeAIEmbeddings
from langchain_community.vectorstores import FAISS

# 1. Load: Point to the 'raw' folder
loader = DirectoryLoader('./data/raw', glob="*.pdf", loader_cls=PyPDFLoader)
docs = loader.load()

# 2. Chunk: Split into smaller pieces for better logic processing
splitter = RecursiveCharacterTextSplitter(chunk_size=1000, chunk_overlap=100)
chunks = splitter.split_documents(docs)

# 3. Embed: Use Gemini to turn text into math vectors
embeddings = GoogleGenerativeAIEmbeddings(model="models/gemini-embedding-001")

# 4. Store: Save the index to 'processed' for Phase 1 persistence[cite: 1]
vector_store = FAISS.from_documents(chunks, embeddings)
vector_store.save_local("./data/processed/faiss_index")

print(f"✅ Knowledge base built with {len(chunks)} document chunks.")
# Out:
# ✅ Knowledge base built with 11 document chunks.

# %%
print("\n--- Document Chunks Inspection ---")
for i, chunk in enumerate(chunks):
    print(f"Chunk {i}:\n{chunk.page_content}\n---\n")

print(f"Total chunks: {len(chunks)}")
# Out:
# --- Document Chunks Inspection ---
# Chunk 0:
# HOTEL BOOKING CONFIRMATION
# Field
# Details
# Confirmation #
# HYD-2026-456789
# Hotel Name
# The Grand Hyderabad Palace
# Address
# Banjara Hills, Hyderabad - 500034
# Phone
# +91-40-67890123
# Email
# bookings@grandhyd.com
# Website
# www.grandhyd.com
# Guest Name
# John David
# Email
# john.david@email.com
# Phone
# 9876543210
# Check-in Date
# June 15, 2026
# Check-in Time
# 2:00 PM (STRICT - Late arrivals after 11:00 PM incur Rs. 50% room charge)
# Check-out Date
# June 20, 2026
# Check-out Time
# 11:00 AM SHARP (Late checkout before 2 PM: Rs. 1,500 | 2-4 PM: Rs. 3,000 | After 4 PM: Full night charge)
# Number of Nights
# 5 nights
# Room Type
# Deluxe Double Room (with city view)
# Room Number
# TBD at check-in
# Room Rate
# Rs. 8,500/night
# Number of Rooms
# 1
# Subtotal
# Rs. 42,500
# GST (18%)
# Rs. 7,650
# Resort Fee
# Rs. 500/night (Rs. 2,500)
# Total Amount
# Rs. 52,650
# Amount Paid
# Rs. 52,650 (100% advance)
# Balance Due
# Rs. 0
# HOTEL POLICIES & FINE PRINT
# Critical Check-in/Check-out Times:
# ---
#
# Chunk 1:
# Balance Due
# Rs. 0
# HOTEL POLICIES & FINE PRINT
# Critical Check-in/Check-out Times:
# Check-in: 2:00 PM (Early check-in at 6:00 AM available for Rs. 2,500 if room available)
# Check-out: 11:00 AM SHARP (Non-negotiable - Late checkout charges: Before 2 PM: Rs. 1,500 | 2-4 PM: Rs. 3,000 | After 4 PM:
# 100% room charge for extra night)
# Late Arrival: Arrivals after 11:00 PM incur 50% room charge even if room is held. Cancellation after 11:00 PM = full charge.
# ---
#
# Chunk 2:
# Cancellation Policy: Cancellations up to 7 days before check-in = 90% refund (10% admin fee). 3-6 days = 50% refund. 1-2
# days = 0% refund. No-show = 100% forfeiture.
# Room Details: Room number will be assigned at check-in. Early room assignment not possible before 12:00 PM. Room rates for
# 2 guests. Additional guests: Rs. 2,000/person/night. Maximum 4 guests per room.
# Amenities: Free WiFi (password provided at check-in), AC, Flat-screen TV, Mini bar (charges apply), Safe, Bath amenities.
# Breakfast: Continental breakfast included (7:00-10:00 AM daily in dining hall). Room service breakfast: Rs. 500 (6:30-10:30 AM).
# Additional Charges: Parking: Rs. 300/day | Laundry: Rs. 100-500/item | Room service: 15% service charge added.
# ---
#
# Chunk 3:
# TERMS & CONDITIONS
# 1. ID VERIFICATION: Government-issued ID required at check-in. Guests must provide valid passport/Aadhar.
# 2. SECURITY DEPOSIT: Rs. 5,000 refundable deposit required (can be charged for damages/missing items).
# 3. HOUSEKEEPING: Daily housekeeping 9:00 AM - 6:00 PM. Do Not Disturb sign honored. Extra cleaning: Rs. 500.
# 4. PETS: NOT allowed except service animals with prior written approval.
# 5. SMOKING POLICY: Designated smoking areas only. Room smoking: Rs. 2,500 fine + room disinfection charge Rs. 1,000.
# 6. PARTIES: No parties/gatherings allowed. Quiet hours: 10:00 PM - 7:00 AM. Noise violation: Rs. 1,000 fine + eviction.
# 7. VALUABLES: Hotel NOT responsible for lost/stolen items. Use in-room safe (access instructions at check-in).
# 8. COMPLAINTS: Report issues within 24 hours for resolution/compensation. After 24 hours, no refund possible.
# 9. PAYMENT: Cash/Credit card/Debit card accepted. GST invoice provided on request. Refunds to original payment method (5-7
# ---
#
# Chunk 4:
# business days).
# 10. LIABILITY: Hotel not responsible for accidents/injuries. Guests assume full liability. Travel insurance recommended.
# IMPORTANT: This booking confirmation is non-transferable. Only John David (named guest) can check in. Third-party check-in
# not allowed.
# ---
#
# Chunk 5:
# HYDERABAD TRAVEL BROCHURE - City of Pearls
# Published: April 30, 2026
# TOP ATTRACTIONS & OPERATING HOURS
# Charminar: Built 1591 | Hours: 9:00 AM - 5:30 PM | Entry: Rs. 25 | Photography: Rs. 50 extra
# Hussain Sagar Lake: Boat rides Rs. 50-150/person | Sunset timing: 6:30 PM | Free entry
# Salarjung Museum: Hours: 10:30 AM - 5:00 PM | Entry: Rs. 150 | CLOSED FRIDAYS
# Ramoji Film City: Hours: 9:00 AM - 6:00 PM | Entry: Rs. 1,500-2,500 | Advance booking required
# BEST TIME TO VISIT
# Optimal: October-February (15-28C). Monsoon: July-Sept (lush, heavy rain). Summer: March-June (up
# to 42C)
# ---
#
# Chunk 6:
# TRAVEL INSURANCE POLICY - COVERAGE & LIMITS
# Coverage Type
# Maximum Limit
# Deductible
# Medical Emergency
# Rs. 5,00,000
# Rs. 1,000
# Trip Cancellation
# 80% of trip cost
# 20% co-pay
# Lost/Damaged Luggage
# Rs. 1,00,000
# 20% of claim
# Flight Delay (>12 hrs)
# Rs. 3,000/hour
# Minimum 12 hours
# Travel Delay
# Rs. 2,000/night
# Maximum 3 nights
# Personal Liability
# Rs. 10,00,000
# Rs. 5,000
# CRITICAL FINE PRINT - INSURANCE EXCLUSIONS
# 1. PRE-EXISTING CONDITIONS: Medical conditions existing BEFORE policy purchase are NOT covered unless declared in
# writing and approved.
# 2. HIGH-RISK ACTIVITIES: Rock climbing, mountaineering, skydiving, bungee jumping EXCLUDED unless special premium is
# paid.
# 3. ALCOHOL/DRUG-RELATED: NO coverage for claims arising from travel while under influence of alcohol or illicit drugs.
# 4. PREGNANCY LIMITS: Coverage ONLY up to 20 weeks. ANY complications AFTER 20 weeks are NOT covered.
# 5. CLAIMS DEADLINE: STRICT - All claims must be REPORTED within 30 DAYS of incident. Late submissions are
# ---
#
# Chunk 7:
# AUTOMATICALLY REJECTED.
# 6. TRIP CANCELLATION: ONLY non-refundable, prepaid expenses covered. Penalties, taxes, and airline surcharges are
# NON-REFUNDABLE.
# 7. TRAVEL AGAINST ADVICE: If travel against medical advice OR government warnings, claims are COMPLETELY VOID.
# 8. BUSINESS TRAVEL: Business-related trips NOT covered. Premium increases 40% if business component exists.
# 9. VISA DENIAL: Only visa application fee is refunded (max Rs. 5,000). All travel-related costs are NOT covered.
# 10. FORCE MAJEURE CLAUSE: War, terrorism, civil unrest, pandemic - NOT covered (unless specific government travel
# warning issued).
# 11. MISSED CONNECTIONS: If you miss flight due to slow immigration/customs processing - NOT covered.
# 12. CLAIM VERIFICATION: Requires ORIGINAL receipts, hotel bills, airline tickets, medical reports, police FIR (if applicable).
# Processing time: 30-45 BUSINESS DAYS.
# 13. TRAVEL AGAINST GOVERNMENT WARNINGS: Travel to areas with government travel warnings = VOID policy.
# ---
#
# Chunk 8:
# AIRLINE CANCELLATION POLICY - REFUND SCHEDULE
# Days Before Departure
# Economy Class
# Business Class
# Admin Fee
# More than 30 days
# 100% Refund
# 100% Refund
# None
# 15-30 days
# 75% Refund
# 90% Refund
# Rs. 1,500
# 7-14 days
# 50% Refund
# 75% Refund
# Rs. 2,500
# 1-6 days
# 25% Refund
# 50% Refund
# Rs. 3,500
# Less than 24 hours
# 0% Refund
# 25% Refund
# Rs. 4,500
# After Check-in
# 0% Refund
# 0% Refund
# Rs. 5,000
# CRITICAL FINE PRINT - AIRLINE CANCELLATION TERMS
# 1. NAME CHANGES: NOT PERMITTED after check-in. Minor spelling corrections (up to 3 letters) incur Rs. 2,500 fee. Full name
# change = rebooking at full new fare.
# 2. NO-SHOW POLICY: Passenger not present at gate 15 MINUTES before departure forfeits ENTIRE ticket value. NO REFUND.
# NO RESCHEDULE.
# 3. BAGGAGE POLICY: Free baggage = 1 piece max 15kg. Additional pieces: Rs. 1,500 each (5kg). Overweight: Rs. 300 per kg.
# Hazardous materials prohibited.
# 4. SPECIAL REQUESTS NOT GUARANTEED: Seat selection, meal preferences, wheelchair assistance must be requested
# ---
#
# Chunk 9:
# MINIMUM 72 HOURS in advance. NO guarantee.
# 5. BOOKING VALIDITY: Ticket is VALID for ONLY 7 DAYS from issue date. After 7 days, booking is AUTOMATICALLY
# CANCELLED with NO refund.
# 6. REFUND PROCESSING: Approved refunds take 15-20 BUSINESS DAYS (excluding weekends/holidays). Bank processing
# adds additional 5-7 days.
# 7. FORCE MAJEURE: War, strike, natural disaster, pandemic = 50% refund OR travel credit (valid 1 YEAR ONLY). No cash
# refund for force majeure.
# 8. SCHEDULE CHANGES: If flight time changed >2 hours = alternative flight offered OR 100% refund. <2 hours = NO
# compensation.
# 9. OVERSELLING: If flight overbooked, volunteer get Rs. 5,000. Non-volunteers: Rs. 10,000 + meals + hotel (if overnight). Only
# CASH compensation.
# 10. CHILD FARES: Children (2-12 years) = 50-75% of adult fare. Infants (<2 years) = 10% of fare with NO seat. Exact name must
# match passport.
# 11. TICKET NON-TRANSFERABILITY: Tickets are STRICTLY NON-TRANSFERABLE. Only named passenger can use.
# ---
#
# Chunk 10:
# Attempting transfer = ticket CANCELLATION.
# 12. FLIGHT MODIFICATIONS: Change flight date = Rs. 2,500 + fare difference. Change route = Rs. 5,000 + fare difference.
# MUST request 24 hours before departure.
# 13. COMPENSATION RULES: EU261 regulations (compensation for delays) NOT APPLICABLE on routes from India. Only
# airline discretion applies.
# 14. ADVANCE DISCOUNT: 10% advance booking discount = COMPLETELY NON-REFUNDABLE. Cannot be cancelled or
# modified. 100% FORFEITURE.
# 15. THIRD-PARTY BOOKINGS: Tickets booked via travel agents/third-party websites = 15% ADDITIONAL penalty on
# cancellations. Refunds go to agent, not passenger.
# 16. GROUND HANDLING: Unattended baggage inspection Rs. 500 | Security screening Rs. 1,000 | Fragile item handling Rs.
# 2,000 per item.
# 17. RESCHEDULING: If rescheduled to flight >24 hours later = meals + accommodation provided. <24 hours = no compensation.
# Contact: 24/7 Helpline | Average wait: 30-45 minutes | Email support: support@airline.com (48-hour response)
# ---
#
# Total chunks: 11

# %%
import google.generativeai as genai

print("Available Embedding Models:")
for m in genai.list_models():
    if 'embedContent' in m.supported_generation_methods:
        print(m.name)
# Out:
# Available Embedding Models:
# models/gemini-embedding-001
# models/gemini-embedding-2-preview
# models/gemini-embedding-2

# %%
# !pip install matplotlib-venn
# Out:
# Requirement already satisfied: matplotlib-venn in /usr/local/lib/python3.12/dist-packages (1.1.2)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.12/dist-packages (from matplotlib-venn) (3.10.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from matplotlib-venn) (1.26.4)
# Requirement already satisfied: scipy in /usr/local/lib/python3.12/dist-packages (from matplotlib-venn) (1.16.3)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->matplotlib-venn) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib->matplotlib-venn) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->matplotlib-venn) (4.62.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->matplotlib-venn) (1.5.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->matplotlib-venn) (23.2)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib->matplotlib-venn) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->matplotlib-venn) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib->matplotlib-venn) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib->matplotlib-venn) (1.17.0)

# %%
# https://pypi.python.org/pypi/libarchive
# !apt-get update -qq && apt-get install -y libarchive-dev && pip install -U libarchive
import libarchive
# Out:
# W: Skipping acquire of configured file 'main/source/Sources' as repository 'https://r2u.stat.illinois.edu/ubuntu jammy InRelease' does not seem to provide it (sources.list entry misspelt?)
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# libarchive-dev is already the newest version (3.6.0-1ubuntu1.6).
# 0 upgraded, 0 newly installed, 0 to remove and 59 not upgraded.
# Requirement already satisfied: libarchive in /usr/local/lib/python3.12/dist-packages (0.4.7)
# Requirement already satisfied: nose in /usr/local/lib/python3.12/dist-packages (from libarchive) (1.3.7)

# %%
# https://pypi.python.org/pypi/pydot
# !apt-get -qq install -y graphviz && pip install pydot
import pydot
# Out:
# Requirement already satisfied: pydot in /usr/local/lib/python3.12/dist-packages (4.0.1)
# Requirement already satisfied: pyparsing>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from pydot) (3.3.2)

# %%
# !pip install cartopy
import cartopy
# Out:
# Collecting cartopy
#   Downloading cartopy-0.25.0-cp312-cp312-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl.metadata (6.1 kB)
# Requirement already satisfied: numpy>=1.23 in /usr/local/lib/python3.12/dist-packages (from cartopy) (1.26.4)
# Requirement already satisfied: matplotlib>=3.6 in /usr/local/lib/python3.12/dist-packages (from cartopy) (3.10.0)
# Requirement already satisfied: shapely>=2.0 in /usr/local/lib/python3.12/dist-packages (from cartopy) (2.1.2)
# Requirement already satisfied: packaging>=21 in /usr/local/lib/python3.12/dist-packages (from cartopy) (23.2)
# Requirement already satisfied: pyshp>=2.3 in /usr/local/lib/python3.12/dist-packages (from cartopy) (3.0.3)
# Requirement already satisfied: pyproj>=3.3.1 in /usr/local/lib/python3.12/dist-packages (from cartopy) (3.7.2)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.6->cartopy) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.6->cartopy) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.6->cartopy) (4.62.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.6->cartopy) (1.5.0)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.6->cartopy) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.6->cartopy) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.6->cartopy) (2.9.0.post0)
# Requirement already satisfied: certifi in /usr/local/lib/python3.12/dist-packages (from pyproj>=3.3.1->cartopy) (2026.4.22)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib>=3.6->cartopy) (1.17.0)
# Downloading cartopy-0.25.0-cp312-cp312-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl (11.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.8/11.8 MB 29.2 MB/s eta 0:00:00
# Installing collected packages: cartopy
# Successfully installed cartopy-0.25.0

# %%
import sys
import os

print("--- Diagnostic Check for LangChain Environment ---")

try:
    import langchain
    print(f"LangChain installed. Version: {langchain.__version__}")
    print(f"LangChain path: {langchain.__path__}")

    # Try to import the specific problematic modules
    try:
        from langchain.chains.retrieval import create_retrieval_chain
        print("Successfully imported 'langchain.chains.retrieval'")
    except ModuleNotFoundError as e:
        print(f"Failed to import 'langchain.chains.retrieval': {e}")

    try:
        from langchain.chains.combine_documents import create_stuff_documents_chain
        print("Successfully imported 'langchain.chains.combine_documents'")
    except ModuleNotFoundError as e:
        print(f"Failed to import 'langchain.chains.combine_documents': {e}")

except ModuleNotFoundError as e:
    print(f"LangChain is not found or cannot be imported: {e}")
    print("Please ensure LangChain is installed correctly and the runtime has been restarted after installation.")

print("--- End of Diagnostic Check ---")

print("\n--- Python sys.path (where Python looks for modules) ---")
for p in sys.path:
    print(p)
print("--- End of sys.path ---")
# Out:
# --- Diagnostic Check for LangChain Environment ---
# LangChain installed. Version: 0.1.20
# LangChain path: ['/usr/local/lib/python3.12/dist-packages/langchain']
# Successfully imported 'langchain.chains.retrieval'
# Successfully imported 'langchain.chains.combine_documents'
# --- End of Diagnostic Check ---
#
# --- Python sys.path (where Python looks for modules) ---
# /content
# /env/python
# /usr/lib/python312.zip
# /usr/lib/python3.12
# /usr/lib/python3.12/lib-dynload
#
# /usr/local/lib/python3.12/dist-packages
# /usr/lib/python3/dist-packages
# /usr/local/lib/python3.12/dist-packages/IPython/extensions
# /root/.ipython
# --- End of sys.path ---

# %%
import os
import langchain

print("--- Inspecting LangChain Package Contents ---")

try:
    langchain_path = langchain.__path__[0]
    print(f"Checking contents of: {langchain_path}")

    # List immediate contents
    package_contents = os.listdir(langchain_path)
    print(f"Immediate contents: {package_contents}")

    # Check for 'chains' module/directory
    chains_path = os.path.join(langchain_path, 'chains')
    if os.path.exists(chains_path):
        if os.path.isdir(chains_path):
            print(f"'chains' directory found at: {chains_path}")
            print(f"Contents of 'chains' directory: {os.listdir(chains_path)}")
        else:
            print(f"'chains.py' file found at: {chains_path}")
    else:
        print("'chains' module/directory NOT found within langchain package.")

except Exception as e:
    print(f"Error inspecting langchain package: {e}")

print("--- End of Package Inspection ---")
# Out:
# --- Inspecting LangChain Package Contents ---
# Checking contents of: /usr/local/lib/python3.12/dist-packages/langchain
# Immediate contents: ['memory', 'text_splitter.py', 'prompts', 'document_loaders', 'chains', 'document_transformers', 'cache.py', 'docstore', 'vectorstores', 'serpapi.py', 'llms', 'globals', 'utilities', 'example_generator.py', 'runnables', 'smith', '__pycache__', 'base_language.py', 'callbacks', 'requests.py', 'adapters', 'load', 'tools', 'graphs', 'retrievers', 'output_parsers', '_api', 'python.py', 'evaluation', 'py.typed', 'input.py', 'agents', 'formatting.py', '__init__.py', 'embeddings', 'chat_loaders', 'storage', 'env.py', 'chat_models', 'schema', 'utils', 'hub.py', 'indexes', 'pydantic_v1', 'sql_database.py', 'model_laboratory.py']
# 'chains' directory found at: /usr/local/lib/python3.12/dist-packages/langchain/chains
# Contents of 'chains' directory: ['combine_documents', 'mapreduce.py', 'llm_requests.py', 'openai_functions', 'base.py', 'llm_math', 'llm_symbolic_math', 'retrieval_qa', 'qa_with_sources', 'qa_generation', 'retrieval.py', 'sequential.py', 'llm.py', 'flare', 'constitutional_ai', 'router', 'example_generator.py', '__pycache__', 'llm_bash', 'conversational_retrieval', 'question_answering', 'structured_output', 'chat_vector_db', 'loading.py', 'query_constructor', 'hyde', 'conversation', 'transform.py', 'history_aware_retriever.py', 'natbot', 'prompt_selector.py', 'sql_database', 'moderation.py', 'api', 'elasticsearch_database', 'llm_summarization_checker', 'openai_tools', '__init__.py', 'ernie_functions', 'summarize', 'llm_checker', 'graph_qa']
# --- End of Package Inspection ---

# %%
from langchain_google_genai import ChatGoogleGenerativeAI
from langchain.chains.retrieval import create_retrieval_chain
from langchain.chains.combine_documents import create_stuff_documents_chain
from langchain_core.prompts import ChatPromptTemplate

# Initialize the LLM
llm = ChatGoogleGenerativeAI(model="gemini-2.5-flash", temperature=0) # Changed model to gemini-2.5-flash

# Define the Persona (The "Intelligent Response" logic)
system_prompt = (
    "You are a professional AI Travel Concierge. "
    "Use the provided context to answer the user's question accurately. "
    "If the answer is not in the context, politely say you don't know. "
    "\n\n"
    "Context: {context}"
)

prompt = ChatPromptTemplate.from_messages([
    ("system", system_prompt),
    ("human", "{input}"),
])

# Create the Retrieval Chain
combine_docs_chain = create_stuff_documents_chain(llm, prompt)
rag_chain = create_retrieval_chain(vector_store.as_retriever(), combine_docs_chain)

# TEST: Run a query to verify the milestone
response = rag_chain.invoke({"input": "What is the check-in time and the refund policy?"})

print("\n--- AI TRAVEL CONCIERGE RESPONSE ---")
print(response) # Print the entire response object for debugging
# Out:
# --- AI TRAVEL CONCIERGE RESPONSE ---
# {'input': 'What is the check-in time and the refund policy?', 'context': [Document(page_content='Balance Due\nRs. 0\nHOTEL POLICIES & FINE PRINT\nCritical Check-in/Check-out Times:\nCheck-in: 2:00 PM (Early check-in at 6:00 AM available for Rs. 2,500 if room available)\nCheck-out: 11:00 AM SHARP (Non-negotiable - Late checkout charges: Before 2 PM: Rs. 1,500 | 2-4 PM: Rs. 3,000 | After 4 PM:\n100% room charge for extra night)\nLate Arrival: Arrivals after 11:00 PM incur 50% room charge even if room is held. Cancellation after 11:00 PM = full charge.', metadata={'source': 'data/raw/Hotel_Booking_Confirmation.pdf', 'page': 0}), Document(page_content='Cancellation Policy: Cancellations up to 7 days before check-in = 90% refund (10% admin fee). 3-6 days = 50% refund. 1-2\ndays = 0% refund. No-show = 100% forfeiture.\nRoom Details: Room number will be assigned at check-in. Early room assignment not possible before 12:00 PM. Room rates for\n2 guests. Additional guests: Rs. 2,000/person/night. Maximum 4 guests per room.\nAmenities: Free WiFi (password provided at check-in), AC, Flat-screen TV, Mini bar (charges apply), Safe, Bath amenities.\nBreakfast: Continental breakfast included (7:00-10:00 AM daily in dining hall). Room service breakfast: Rs. 500 (6:30-10:30 AM).\nAdditional Charges: Parking: Rs. 300/day | Laundry: Rs. 100-500/item | Room service: 15% service charge added.', metadata={'source': 'data/raw/Hotel_Booking_Confirmation.pdf', 'page': 1}), Document(page_content='TERMS & CONDITIONS\n1. ID VERIFICATION: Government-issued ID required at check-in. Guests must provide valid passport/Aadhar.\n2. SECURITY DEPOSIT: Rs. 5,000 refundable deposit required (can be charged for damages/missing items).\n3. HOUSEKEEPING: Daily housekeeping 9:00 AM - 6:00 PM. Do Not Disturb sign honored. Extra cleaning: Rs. 500.\n4. PETS: NOT allowed except service animals with prior written approval.\n5. SMOKING POLICY: Designated smoking areas only. Room smoking: Rs. 2,500 fine + room disinfection charge Rs. 1,000.\n6. PARTIES: No parties/gatherings allowed. Quiet hours: 10:00 PM - 7:00 AM. Noise violation: Rs. 1,000 fine + eviction.\n7. VALUABLES: Hotel NOT responsible for lost/stolen items. Use in-room safe (access instructions at check-in).\n8. COMPLAINTS: Report issues within 24 hours for resolution/compensation. After 24 hours, no refund possible.\n9. PAYMENT: Cash/Credit card/Debit card accepted. GST invoice provided on request. Refunds to original payment method (5-7', metadata={'source': 'data/raw/Hotel_Booking_Confirmation.pdf', 'page': 2}), Document(page_content='business days).\n10. LIABILITY: Hotel not responsible for accidents/injuries. Guests assume full liability. Travel insurance recommended.\nIMPORTANT: This booking confirmation is non-transferable. Only John David (named guest) can check in. Third-party check-in\nnot allowed.', metadata={'source': 'data/raw/Hotel_Booking_Confirmation.pdf', 'page': 2})], 'answer': 'The standard check-in time is 2:00 PM.\n\nThe refund policy is as follows:\n*   Cancellations up to 7 days before check-in: 90% refund (10% admin fee).\n*   Cancellations 3-6 days before check-in: 50% refund.\n*   Cancellations 1-2 days before check-in: 0% refund.\n*   No-show: 100% forfeiture.'}

# %%
# %%writefile app.py
!pip install streamlit
import streamlit as st
import os
from langchain_google_genai import ChatGoogleGenerativeAI, GoogleGenerativeAIEmbeddings
from langchain_community.document_loaders import PyPDFLoader
from langchain_community.vectorstores import FAISS
from langchain.chains import RetrievalQA

# 1. Page Setup
st.set_page_config(page_title="Travel AI", layout="centered")
st.title("✈️ Travel Concierge")

# 2. Key Handling
api_key = st.sidebar.text_input("Gemini API Key", type="password")

if api_key:
    os.environ["GOOGLE_API_KEY"] = api_key

    # Initialize Models
    llm = ChatGoogleGenerativeAI(model="gemini-1.5-flash")
    embeddings = GoogleGenerativeAIEmbeddings(model="models/embedding-001")

    # 3. Simple Knowledge Base
    @st.cache_resource
    def load_kb():
        path = "./data/raw"
        if os.path.exists(path):
            files = [f for f in os.listdir(path) if f.endswith('.pdf')]
            if files:
                # Load the first PDF found
                loader = PyPDFLoader(os.path.join(path, files[0]))
                # split docs into chunks automatically
                pages = loader.load_and_split()
                return FAISS.from_documents(pages, embeddings)
        return None

    vector_db = load_kb()

    if vector_db:
        # 4. Chat Interface
        query = st.chat_input("Ask a question about your trip:")

        if query:
            with st.chat_message("user"):
                st.markdown(query)

            # Use the most stable QA chain available
            qa_chain = RetrievalQA.from_chain_type(
                llm=llm,
                chain_type="stuff",
                retriever=vector_db.as_retriever()
            )

            with st.chat_message("assistant"):
                response = qa_chain.run(query)
                st.markdown(response)
    else:
        st.error("⚠️ No PDF found in 'data/raw/'. Check your GitHub folders!")
else:
    st.info("Please enter your API Key in the sidebar.")
# Out:
# Writing app.py

# %%
# %%writefile requirements.txt
# streamlit
# langchain
# langchain-community
# langchain-google-genai
# google-generativeai
# pypdf
# faiss-cpu
# Out:
# Writing requirements.txt
